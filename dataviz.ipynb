# %%
# This script will generate data viz

# I'm doing a O'Reilly's tutorial 
# https://www.oreilly.com/learning/data-visualization-with-seaborn

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns

x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), x, np.cos(x));

# %%
sns.set()
plt.plot(x, np.sin(x), x, np.cos(x));

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], normed=True, alpha=0.5)

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
sns.distplot(data['x'])

# %%
sns.kdeplot(data)

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde')

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='hex')

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=2.5)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15))

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot("day", "total_bill", "sex", data=tips, kind="box")
    g.set_axis_labels("Day", "Total Bill")

# %%
with sns.axes_style('white'):
    sns.jointplot("total_bill", "tip", data=tips, kind='hex')

# %%
sns.jointplot("total_bill", "tip", data=tips, kind='reg');

# %%
wine_test = pd.read_csv('dataset/wine.data_test.csv')
wine_test["isCorrect"] = wine_test.expectedOutput == wine_test.predictedOutput
wine_test
# Out:
#     instanceID  expectedOutput  predictedOutput  isCorrect
# 0            0               2                2       True
# 1            1               2                2       True
# 2            2               2                1      False
# 3            3               3                3       True
# 4            4               1                1       True
# 5            5               2                2       True
# 6            6               2                2       True
# 7            7               1                1       True
# 8            8               3                3       True
# 9            9               3                3       True
# 10          10               2                2       True
# 11          11               1                1       True
# 12          12               1                1       True
# 13          13               1                1       True
# 14          14               1                1       True
# 15          15               2                2       True
# 16          16               2                2       True
# 17          17               2                3      False
# 18          18               3                3       True
# 19          19               2                2       True
# 20          20               1                1       True
# 21          21               2                2       True
# 22          22               1                1       True
# 23          23               1                1       True
# 24          24               2                2       True
# 25          25               3                3       True
# 26          26               2                1      False
# 27          27               2                2       True
# 28          28               2                2       True
# 29          29               2                1      False
# 30          30               2                2       True
# 31          31               3                3       True
# 32          32               1                1       True
# 33          33               2                2       True
# 34          34               2                2       True
# 35          35               2                2       True

# %%
# TODO: comparar a performance média nos quesitos 
# 1. acurácia ( TP + TN ) / Total
# 2. precisão TP / (TP + FP)
# 3. recall TP / (TP + FN)
# Extra. F1 Score

# %%
cmc_test = pd.read_csv('dataset/cmc.data_test.csv')
cmc_test["isCorrect"] = cmc_test.expectedOutput == cmc_test.predictedOutput
cmc_test
# Out:
#      instanceID  expectedOutput  predictedOutput  isCorrect
# 0             0               2                3      False
# 1             1               1                3      False
# 2             2               1                3      False
# 3             3               1                3      False
# 4             4               2                3      False
# 5             5               1                3      False
# 6             6               1                3      False
# 7             7               1                3      False
# 8             8               3                3       True
# 9             9               1                3      False
# 10           10               1                3      False
# 11           11               3                3       True
# 12           12               3                3       True
# 13           13               1                3      False
# 14           14               1                3      False
# 15           15               3                3       True
# 16           16               2                3      False
# 17           17               1                3      False
# 18           18               1                3      False
# 19           19               2                3      False
# 20           20               3                3       True
# 21           21               1                3      False
# 22           22               1                3      False
# 23           23               1                3      False
# 24           24               1                3      False
# 25           25               1                3      False
# 26           26               3                3       True
# 27           27               2                3      False
# 28           28               3                3       True
# 29           29               3                3       True
# ..          ...             ...              ...        ...
# 265         265               3                3       True
# 266         266               3                3       True
# 267         267               2                3      False
# 268         268               2                3      False
# 269         269               2                3      False
# 270         270               1                3      False
# 271         271               3                3       True
# 272         272               1                3      False
# 273         273               2                3      False
# 274         274               3                3       True
# 275         275               3                3       True
# 276         276               3                3       True
# 277         277               1                1       True
# 278         278               3                3       True
# 279         279               2                3      False
# 280         280               3                3       True
# 281         281               2                3      False
# 282         282               2                3      False
# 283         283               3                3       True
# 284         284               1                3      False
# 285         285               3                3       True
# 286         286               3                3       True
# 287         287               2                3      False
# 288         288               2                3      False
# 289         289               1                3      False
# 290         290               2                3      False
# 291         291               3                3       True
# 292         292               3                3       True
# 293         293               2                3      False
# 294         294               1                3      False
#
# [295 rows x 4 columns]

# %%
haberman_test = pd.read_csv('dataset/haberman.data_test.csv')
haberman_test["isCorrect"] = haberman_test.expectedOutput == haberman_test.predictedOutput
haberman_test
# Out:
#     instanceID  expectedOutput  predictedOutput  isCorrect
# 0            0               1                1       True
# 1            1               1                1       True
# 2            2               1                1       True
# 3            3               2                1      False
# 4            4               1                1       True
# 5            5               2                1      False
# 6            6               1                1       True
# 7            7               2                1      False
# 8            8               1                1       True
# 9            9               1                1       True
# 10          10               1                1       True
# 11          11               2                2       True
# 12          12               1                1       True
# 13          13               1                1       True
# 14          14               1                1       True
# 15          15               1                1       True
# 16          16               1                1       True
# 17          17               2                1      False
# 18          18               2                1      False
# 19          19               1                1       True
# 20          20               1                1       True
# 21          21               1                1       True
# 22          22               1                1       True
# 23          23               1                1       True
# 24          24               2                1      False
# 25          25               1                1       True
# 26          26               2                1      False
# 27          27               2                1      False
# 28          28               1                1       True
# 29          29               1                1       True
# ..         ...             ...              ...        ...
# 32          32               1                1       True
# 33          33               1                1       True
# 34          34               1                1       True
# 35          35               1                1       True
# 36          36               1                1       True
# 37          37               2                1      False
# 38          38               1                1       True
# 39          39               1                1       True
# 40          40               1                1       True
# 41          41               1                1       True
# 42          42               2                1      False
# 43          43               1                1       True
# 44          44               2                1      False
# 45          45               1                1       True
# 46          46               1                1       True
# 47          47               1                1       True
# 48          48               1                1       True
# 49          49               2                1      False
# 50          50               2                1      False
# 51          51               1                1       True
# 52          52               1                1       True
# 53          53               1                1       True
# 54          54               2                1      False
# 55          55               2                1      False
# 56          56               1                1       True
# 57          57               1                1       True
# 58          58               1                1       True
# 59          59               1                1       True
# 60          60               1                1       True
# 61          61               2                1      False
#
# [62 rows x 4 columns]

# %%
wine_train = pd.read_csv('dataset/wine.data_1_train.csv')
plt.plot(wine_train.error, label='5')
wine_train = pd.read_csv('dataset/wine.data_2_train.csv')
plt.plot(wine_train.error, label='11')
wine_train = pd.read_csv('dataset/wine.data_3_train.csv')
plt.plot(wine_train.error, label='2')

plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.savefig('graphs/wine.png')

# mais denso é melhor

# %%
haberman_train = pd.read_csv('dataset/haberman.data_1_train.csv')
plt.plot(haberman_train.error, label='5')
haberman_train = pd.read_csv('dataset/haberman.data_2_train.csv')
plt.plot(haberman_train.error, label='11')
haberman_train = pd.read_csv('dataset/haberman.data_3_train.csv')
plt.plot(haberman_train.error, label='2')

plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.savefig('graphs/haberman.png')

# mais denso é melhor

# %%
cmc_train = pd.read_csv('dataset/cmc.data_1_train.csv')
plt.plot(cmc_train.error, label='5')
cmc_train = pd.read_csv('dataset/cmc.data_2_train.csv')
plt.plot(cmc_train.error, label='11')
cmc_train = pd.read_csv('dataset/cmc.data_3_train.csv')
plt.plot(cmc_train.error, label='2')

plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.savefig('graphs/cmc.png')

# mais denso é melhor

# %%
from sklearn.metrics import confusion_matrix

cmc_test = pd.read_csv('dataset/cmc.data_2_test.csv')
# cmc_test["isCorrect"] = cmc_test.expectedOutput == cmc_test.predictedOutput
cnf_matrix = confusion_matrix(cmc_test.expectedOutput,cmc_test.predictedOutput)
plt.figure()
plt.show()


haberman_test = pd.read_csv('dataset/haberman.data_2_test.csv')
# haberman_test["isCorrect"] = haberman_test.expectedOutput == haberman_test.predictedOutput


wine_test = pd.read_csv('dataset/wine.data_2_test.csv')
# wine_test["isCorrect"] = wine_test.expectedOutput == wine_test.predictedOutput
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-af4db21f130c> in <module>()
#       4 # cmc_test["isCorrect"] = cmc_test.expectedOutput == cmc_test.predictedOutput
#       5 cnf_matrix = confusion_matrix(cmc_test.expectedOutput,cmc_test.predictedOutput)
# ----> 6 plt.figure(cnf_matrix)
#       7 plt.show()
#       8
#
# /Users/fialves1/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, **kwargs)
#     508             num = allnums[inum]
#     509     else:
# --> 510         num = int(num)  # crude validation of num argument
#     511
#     512     figManager = _pylab_helpers.Gcf.get_fig_manager(num)
#
# TypeError: only length-1 arrays can be converted to Python scalars

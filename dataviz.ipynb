# %%
# This script will generate data viz

# I'm doing a O'Reilly's tutorial 
# https://www.oreilly.com/learning/data-visualization-with-seaborn

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns

x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), x, np.cos(x));

# %%
sns.set()
plt.plot(x, np.sin(x), x, np.cos(x));

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

for col in 'xy':
    plt.hist(data[col], normed=True, alpha=0.5)

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
sns.distplot(data['x'])

# %%
sns.kdeplot(data)

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde')

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='hex')

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=2.5)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15))

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot("day", "total_bill", "sex", data=tips, kind="box")
    g.set_axis_labels("Day", "Total Bill")

# %%
with sns.axes_style('white'):
    sns.jointplot("total_bill", "tip", data=tips, kind='hex')

# %%
sns.jointplot("total_bill", "tip", data=tips, kind='reg');

# %%
wine_test = pd.read_csv('dataset/wine.data_test.csv')
wine_test["isCorrect"] = wine_test.expectedOutput == wine_test.predictedOutput
wine_test
# Out:
#     instanceID  expectedOutput  predictedOutput  isCorrect
# 0            0               2                2       True
# 1            1               2                2       True
# 2            2               2                1      False
# 3            3               3                3       True
# 4            4               1                1       True
# 5            5               2                2       True
# 6            6               2                2       True
# 7            7               1                1       True
# 8            8               3                3       True
# 9            9               3                3       True
# 10          10               2                2       True
# 11          11               1                1       True
# 12          12               1                1       True
# 13          13               1                1       True
# 14          14               1                1       True
# ...

# %%
# TODO: comparar a performance média nos quesitos 
# 1. acurácia ( TP + TN ) / Total
# 2. precisão TP / (TP + FP)
# 3. recall TP / (TP + FN)
# Extra. F1 Score

# %%
cmc_test = pd.read_csv('dataset/cmc.data_test.csv')
cmc_test["isCorrect"] = cmc_test.expectedOutput == cmc_test.predictedOutput
cmc_test
# Out:
#      instanceID  expectedOutput  predictedOutput  isCorrect
# 0             0               2                3      False
# 1             1               1                3      False
# 2             2               1                3      False
# 3             3               1                3      False
# 4             4               2                3      False
# 5             5               1                3      False
# 6             6               1                3      False
# 7             7               1                3      False
# 8             8               3                3       True
# 9             9               1                3      False
# 10           10               1                3      False
# 11           11               3                3       True
# 12           12               3                3       True
# 13           13               1                3      False
# 14           14               1                3      False
# ...

# %%
haberman_test = pd.read_csv('dataset/haberman.data_test.csv')
haberman_test["isCorrect"] = haberman_test.expectedOutput == haberman_test.predictedOutput
haberman_test
# Out:
#     instanceID  expectedOutput  predictedOutput  isCorrect
# 0            0               1                1       True
# 1            1               1                1       True
# 2            2               1                1       True
# 3            3               2                1      False
# 4            4               1                1       True
# 5            5               2                1      False
# 6            6               1                1       True
# 7            7               2                1      False
# 8            8               1                1       True
# 9            9               1                1       True
# 10          10               1                1       True
# 11          11               2                2       True
# 12          12               1                1       True
# 13          13               1                1       True
# 14          14               1                1       True
# ...

# %%
plt.ylabel("Error")
plt.xlabel("Instances")
wine_train = pd.read_csv('dataset/wine.data_1_train.csv')
plt.plot(wine_train.error, label='5')
wine_train = pd.read_csv('dataset/wine.data_2_train.csv')
plt.plot(wine_train.error, label='11')
wine_train = pd.read_csv('dataset/wine.data_3_train.csv')
plt.plot(wine_train.error, label='2')

plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.savefig('graphs/wine.png')

# mais denso é melhor

# %%
plt.ylabel("Error")
plt.xlabel("Instances")
haberman_train = pd.read_csv('dataset/haberman.data_1_train.csv')
plt.plot(haberman_train.error, label='5')
haberman_train = pd.read_csv('dataset/haberman.data_2_train.csv')
plt.plot(haberman_train.error, label='11')
haberman_train = pd.read_csv('dataset/haberman.data_3_train.csv')
plt.plot(haberman_train.error, label='2')

plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.savefig('graphs/haberman.png')

# mais denso é melhor

# %%
plt.ylabel("Error")
plt.xlabel("Instances")
cmc_train = pd.read_csv('dataset/cmc.data_1_train.csv')
plt.plot(cmc_train.error, label='5')
cmc_train = pd.read_csv('dataset/cmc.data_2_train.csv')
plt.plot(cmc_train.error, label='11')
cmc_train = pd.read_csv('dataset/cmc.data_3_train.csv')
plt.plot(cmc_train.error, label='2')

plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.savefig('graphs/cmc.png')

# mais denso é melhor

# %%
# compara a performance média nos quesitos 
# 1. acurácia ( TP + TN ) / Total
# 2. precisão TP / (TP + FP)
# 3. recall TP / (TP + FN)
# Extra. F1 Score

# %%
from pandas_ml import ConfusionMatrix
cmc_test = pd.read_csv('dataset/cmc.data_2_test.csv')
cm = ConfusionMatrix(cmc_test.expectedOutput,cmc_test.predictedOutput)
cm.plot() # plots confusion matrix
cm.print_stats() # show accuracy
# Out:
# Confusion Matrix:
#
# Predicted    1   2  3  __all__
# Actual
# 1          120   7  1      128
# 2           60   8  0       68
# 3           86  13  0       99
# __all__    266  28  1      295
#
#
# Overall Statistics:
#
# Accuracy: 0.433898305085
# 95% CI: (0.37656378542347008, 0.49257395727797637)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 1.0
# Kappa: 0.0335268960647
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                        1          2           3
# Population                                   295        295         295
# P: Condition positive                        128         68          99
# N: Condition negative                        167        227         196
# Test outcome positive                        266         28           1
# Test outcome negative                         29        267         294
# TP: True Positive                            120          8           0
# ...

# %%
haberman_test = pd.read_csv('dataset/haberman.data_2_test.csv')
cm = ConfusionMatrix(haberman_test.expectedOutput,haberman_test.predictedOutput)
cm.plot() # plots confusion matrix
cm.print_stats() # show stats
# Out:
# Confusion Matrix:
#
# Predicted  1   2  __all__
# Actual
# 1          0  47       47
# 2          0  15       15
# __all__    0  62       62
#
#
# Overall Statistics:
#
# Accuracy: 0.241935483871
# 95% CI: (0.14218603584801809, 0.36744970718594461)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 1.0
# Kappa: 0.0
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                       1         2
# Population                                   62        62
# P: Condition positive                        47        15
# N: Condition negative                        15        47
# Test outcome positive                         0        62
# Test outcome negative                        62         0
# TP: True Positive                             0        15
# TN: True Negative                            15         0
# FP: False Positive                            0        47
# FN: False Negative                           47         0
# ...

# %%
wine_test = pd.read_csv('dataset/wine.data_2_test.csv')
cm = ConfusionMatrix(wine_test.expectedOutput,wine_test.predictedOutput)
cm.plot() # plots confusion matrix
cm.print_stats() # show stats
# Out:
# Confusion Matrix:
#
# Predicted  1   2   3  __all__
# Actual
# 1          8   4   0       12
# 2          0  12   0       12
# 3          0   1  11       12
# __all__    8  17  11       36
#
#
# Overall Statistics:
#
# Accuracy: 0.861111111111
# 95% CI: (0.70502505188936837, 0.95332233939690969)
# No Information Rate: ToDo
# P-Value [Acc > NIR]: 1.41308663785e-06
# Kappa: 0.791666666667
# Mcnemar's Test P-Value: ToDo
#
#
# Class Statistics:
#
# Classes                                       1         2          3
# Population                                   36        36         36
# P: Condition positive                        12        12         12
# N: Condition negative                        24        24         24
# Test outcome positive                         8        17         11
# Test outcome negative                        28        19         25
# TP: True Positive                             8        12         11
# ...
